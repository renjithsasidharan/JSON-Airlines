# %% [markdown]
# <a href="https://colab.research.google.com/github/renjithsasidharan/JSON-Airlines/blob/master/LayoutLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# !cp /gdrive/My\ Drive/training_data/layoutlm/layoutlm.zip ./

# %%
# !unzip layoutlm.zip
#!cp -r ./layoutlm/* ./

# %%
# !pip install .

# %%
# %%writefile setup.sh
#
# export CUDA_HOME=/usr/local/cuda-10.1
# git clone https://github.com/NVIDIA/apex
# pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./apex
# Out:
# Writing setup.sh

# %%
# !sh setup.sh

# %%
# !rm -rf output

# %%
# !sh train.sh
# Out:
# 2020-05-31 00:55:04.451702: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# ...

# %%
# !python examples/seq_labeling/run_seq_labeling.py  --data_dir er_data \
                            --model_type layoutlm \
                            --model_name_or_path layoutlm-base-uncased \
                            --do_lower_case \
                            --max_seq_length 512 \
                            --output_dir output \
                            --labels er_data/labels.txt \
                            --fp16 \
                            --do_eval
# Out:
# 2020-05-31 01:40:16.040176: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: True
# ...

# %%
 # !tar -zcf output.tar.gz output

# %%
# !cp ./output.tar.gz /gdrive/My\ Drive/training_data/layoutlm
